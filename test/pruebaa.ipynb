# %%
import pandas as pd

# %%
news_values = pd.read_csv('../data/csv/news_from_2024-01-01_to_2026-03-04.csv')

# %%
news_values
# Out:
#                                                     id  \
# 0    971fcae532f2cb16e718a30402fefccfd0c2790d3d103d...
# 1    afcdfc8597a08d36276ccaf4df4df19a86b0800650d5b0...
# 2    1ba810eae81c9e5f5e78b42722fd8be1829672e9bd2db9...
# 3    516d0af2eed7abd373aad711ad6beaf02e7ade72ed2338...
# 4    ce06d9c128a7ff73b4f51d3a5a9430f55c6fa3919a136f...
# ..                                                 ...
# 945        hgPAbEhurZephLC6qTe77gHbaAAFaPYuNdGXSEnR1P4
# 946        OErIFHL3nQI2n06kDw44IGK1r9ZyvbskSvS_LPm2USA
# 947        3IUGXOeHB55VkBjocFD-iQnAVJ3wfl4hoqYnr_UBn58
# 948        wpvx5wjVuWuenU-979enj0RjmH0u7Z_632FYzmjxTTA
# 949        U4r00hhypLGaEeLAxqyaa6ux9FmkVToV8Di0YH4uAFc
#
#                                              publisher  \
# 0    {'name': 'GlobeNewswire Inc.', 'homepage_url':...
# 1    {'name': 'Investing.com', 'homepage_url': 'htt...
# 2    {'name': 'Investing.com', 'homepage_url': 'htt...
# 3    {'name': 'GlobeNewswire Inc.', 'homepage_url':...
# ...

# %%
news_values['insights'].loc[55]
# Out:
# "[{'ticker': 'AXP', 'sentiment': 'positive', 'sentiment_reasoning': 'Outperformed peers with 40% share price increase, lower valuation metrics, record quarterly revenue, raised full-year sales guidance, and lower credit losses due to affluent client base'}, {'ticker': 'V', 'sentiment': 'neutral', 'sentiment_reasoning': 'Reported solid earnings with revenue and EPS growth, but guided to lower expected revenue and anticipated higher operating expenses in 2026'}, {'ticker': 'MA', 'sentiment': 'neutral', 'sentiment_reasoning': 'Achieved top and bottom-line beat with strong revenue growth, but faces potential revenue headwind from Capital One migration and higher valuation compared to peers'}]"

# %%
news_values2 = pd.read_csv('../data/csv/final.csv')

# %%
news_values2
# Out:
#                      date                                              title  \
# 0    2026-03-04T22:39:00Z  Bitget Wallet amplía su tarjeta cripto sin com...
# 1    2026-03-04T17:28:00Z  Meta Is Bringing Back Stablecoin Payments—This...
# 2    2026-03-04T16:01:00Z  SoFi Gains Traction as Mastercard Deal Brings ...
# 3    2026-03-04T02:44:00Z  Bitget Wallet Expands Zero-Fee Crypto Card in ...
# 4    2026-03-03T22:20:48Z  Stock Market Today, March 3: SoFi Technologies...
# ..                    ...                                                ...
# 933  2023-07-18T15:58:00Z  Mastercard (MA) & Geidea Partner to Drive Paym...
# 934  2023-07-18T10:40:00Z  3 Payment Stocks Gaining From Improving Consum...
# 935  2023-07-18T09:33:00Z   3 Warren Buffett Stocks That Everyone Should Own
# 936  2023-07-17T21:45:18Z  MasterCard (MA) Stock Sinks As Market Gains: W...
# 937  2023-07-17T17:12:00Z  Mastercard (MA) & DTS Unite to Minimize Digita...
#
# ...

# %%
news_values2.loc[news_values2['date'] == '2026-03-04T17:28:00Z']
# Out:
#                    date                                              title  \
# 1  2026-03-04T17:28:00Z  Meta Is Bringing Back Stablecoin Payments—This...
#
#                                            real_news   ma  axp  cof  es_ingles
# 1  Meta plans to launch a stablecoin with a third...  0.0  0.0  0.0       True

# %%
for i in news_values.loc[news_values['published_utc'] == '2026-03-04T17:28:00Z']['insights']:
    print(i)
# Out:
# [{'ticker': 'META', 'sentiment': 'positive', 'sentiment_reasoning': "Meta's renewed stablecoin initiative is positioned favorably with improved regulatory conditions (GENIUS Act), growing market adoption ($30B to $300B in stablecoin supply since 2020), and clear business benefits including reduced cross-border payment costs, enhanced creator incentives, and potential new transaction-based revenue streams. The strategy leverages Meta's significant international revenue (56% from outside US/Canada) and could strengthen its core advertising business through increased engagement."}, {'ticker': 'MA', 'sentiment': 'neutral', 'sentiment_reasoning': "Mastercard is mentioned only as a historical reference point—it left Meta's Libra Association in 2019. The article does not discuss current implications for Mastercard regarding Meta's new stablecoin plans."}, {'ticker': 'V', 'sentiment': 'neutral', 'sentiment_reasoning': "Visa is mentioned only as a historical reference point—it left Meta's Lib
# ...
