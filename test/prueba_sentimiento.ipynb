# %%
import pandas as pd

# %%
from transformers import BertTokenizer, BertForSequenceClassification, pipeline

# %%
news_values = pd.read_csv('../data/csv/final.csv')

# %%
news_values
# Out:
#                      date                                              title  \
# 0    2026-03-04T22:39:00Z  Bitget Wallet amplía su tarjeta cripto sin com...
# 1    2026-03-04T17:28:00Z  Meta Is Bringing Back Stablecoin Payments—This...
# 2    2026-03-04T16:01:00Z  SoFi Gains Traction as Mastercard Deal Brings ...
# 3    2026-03-04T02:44:00Z  Bitget Wallet Expands Zero-Fee Crypto Card in ...
# 4    2026-03-03T22:20:48Z  Stock Market Today, March 3: SoFi Technologies...
# ..                    ...                                                ...
# 933  2023-07-18T15:58:00Z  Mastercard (MA) & Geidea Partner to Drive Paym...
# 934  2023-07-18T10:40:00Z  3 Payment Stocks Gaining From Improving Consum...
# 935  2023-07-18T09:33:00Z   3 Warren Buffett Stocks That Everyone Should Own
# 936  2023-07-17T21:45:18Z  MasterCard (MA) Stock Sinks As Market Gains: W...
# 937  2023-07-17T17:12:00Z  Mastercard (MA) & DTS Unite to Minimize Digita...
#
# ...

# %%
nlp = pipeline("sentiment-analysis", model="ProsusAI/finbert")
# Out:
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# BertForSequenceClassification LOAD REPORT from: ProsusAI/finbert
# Key                          | Status     |  |
# -----------------------------+------------+--+-
# bert.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ...

# %%
value = nlp( f'Regarding Mastercard: {news_values.loc[0]['real_news']}' )

# %%
value
# Out:
# [{'label': 'neutral', 'score': 0.7797413468360901}]

# %%
news_values.loc[0]['real_news']
# Out:
# 'Bitget Wallet has launched a crypto payment card in Latin America in partnership with Immersve, enabling users to spend stablecoins (USDC) directly from self-custody wallets with automatic USD conversion. The card offers no reload, monthly, or inactivity fees, with full reimbursement of exchange and conversion fees within monthly limits, providing approximately 1.7% savings compared to traditional cards. The card is available across 11 Latin American countries and works with Apple Pay and Google Pay at over 150 million Mastercard-accepting merchants worldwide.'

# %%
data1 = pd.read_csv('../data/csv/final.csv')

# %%
data1
# Out:
#                           date  \
# 0    2026-03-04 00:00:00+00:00
# 1    2026-03-04 00:00:00+00:00
# 2    2026-03-04 00:00:00+00:00
# 3    2026-03-04 00:00:00+00:00
# 4    2026-03-03 00:00:00+00:00
# ..                         ...
# 935  2023-07-18 00:00:00+00:00
# 936  2023-07-18 00:00:00+00:00
# 937  2023-07-18 00:00:00+00:00
# 938  2023-07-17 00:00:00+00:00
# 939  2023-07-17 00:00:00+00:00
#
#                                                  title  \
# 0    Bitget Wallet amplía su tarjeta cripto sin com...
# 1    Meta Is Bringing Back Stablecoin Payments—This...
# 2    SoFi Gains Traction as Mastercard Deal Brings ...
# 3    Bitget Wallet Expands Zero-Fee Crypto Card in ...
# 4    Stock Market Today, March 3: SoFi Technologies...
# ..                                                 ...
# 935  Mastercard (MA) & Geidea Partner to Drive Paym...
# 936  3 Payment Stocks Gaining From Improving Consum...
# 937   3 Warren Buffett Stocks That Everyone Should Own
# ...

# %%
data1.loc[ data1['news_score'] < 0 ]
# Out:
#                           date  \
# 4    2026-03-03 00:00:00+00:00
# 5    2026-03-03 00:00:00+00:00
# 8    2026-02-22 00:00:00+00:00
# 10   2026-02-18 00:00:00+00:00
# 12   2026-02-17 00:00:00+00:00
# ..                         ...
# 913  2023-07-27 00:00:00+00:00
# 915  2023-07-27 00:00:00+00:00
# 917  2023-07-27 00:00:00+00:00
# 934  2023-07-19 00:00:00+00:00
# 938  2023-07-17 00:00:00+00:00
#
#                                                  title  \
# 4    Stock Market Today, March 3: SoFi Technologies...
# 5               The Financial Sector Is Under Pressure
# 8     2 Financial Stocks Poised for a Comeback in 2026
# 10   The Fed's Next Move: Why Traders Are Piling In...
# 12   Cloudflare, Mastercard To Develop Cybersecurit...
# ..                                                 ...
# 913                                   We'll Do It Live
# 915  Mastercard moves to stop cannabis purchases wi...
# 917  Oil will hit $90 a barrel, says Bank of Americ...
# ...

# %%
data1.loc[4]['real_news']
# Out:
# "SoFi Technologies rose 1.22% to $18.61 on March 3, 2026, driven by a deepened stablecoin partnership with Mastercard and CEO Anthony Noto's $1 million insider share purchase. Under the partnership, SoFi's stablecoin (SoFiUSD) will be offered as a settlement option across Mastercard's payment network. The broader market declined, with the S&P 500 falling 0.94% and Nasdaq dropping 1.02%."

# %%
value2 = nlp( f'Regarding Mastercard: {data1.loc[4]['real_news']}' )

# %%
value2
# Out:
# [{'label': 'negative', 'score': 0.9658439755439758}]

# %%
#es una noticia positiva... finbert es muy generico, voy a usar el multiplicador con la puntuacion de la api de noticias...

# %%
value3 = pd.read_csv('../data/csv/final.csv')

# %%
value3
# Out:
#                           date  \
# 0    2026-03-04 00:00:00+00:00
# 1    2026-03-04 00:00:00+00:00
# 2    2026-03-04 00:00:00+00:00
# 3    2026-03-04 00:00:00+00:00
# 4    2026-03-03 00:00:00+00:00
# ..                         ...
# 935  2023-07-18 00:00:00+00:00
# 936  2023-07-18 00:00:00+00:00
# 937  2023-07-18 00:00:00+00:00
# 938  2023-07-17 00:00:00+00:00
# 939  2023-07-17 00:00:00+00:00
#
#                                                  title  \
# 0    Bitget Wallet amplía su tarjeta cripto sin com...
# 1    Meta Is Bringing Back Stablecoin Payments—This...
# 2    SoFi Gains Traction as Mastercard Deal Brings ...
# 3    Bitget Wallet Expands Zero-Fee Crypto Card in ...
# 4    Stock Market Today, March 3: SoFi Technologies...
# ..                                                 ...
# 935  Mastercard (MA) & Geidea Partner to Drive Paym...
# 936  3 Payment Stocks Gaining From Improving Consum...
# 937   3 Warren Buffett Stocks That Everyone Should Own
# ...

# %%
value3.loc[938]['real_news']
# Out:
# 'MasterCard (MA) closed the most recent trading day at $402.20, moving -0.08% from the previous trading session.'
